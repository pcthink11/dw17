# %%
# %matplotlib notebook
import matplotlib.pyplot as plt1

import pandas as pd
df=pd.read_csv("E:\\Boston\\boston_corrected.txt",delimiter="\t",index_col="OBS.")
pd.plotting.scatter_matrix(df[['CRIM','LSTAT','MEDV']], alpha=0.8, figsize=(24, 24), diagonal='hist')
#plt1.savefig("scatter-1.png")
# Out:
# <img src="data:image/png;base64,..." width="2400">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1A140470>,
# ...
#       dtype=object)
